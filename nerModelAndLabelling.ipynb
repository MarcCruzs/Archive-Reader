# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#   Using cached https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
# ...
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy

# Load the pre-trained English NER model
nlp = spacy.load("en_core_web_sm")

def ner_on_text_file(file_path):
    # Read the text from the file
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()

    # Process the text with the NER model
    doc = nlp(text)

    # Print the named entities found in the text
    for ent in doc.ents:
        print(f"Entity: {ent.text}, Type: {ent.label_}")

# Example usage
file_path = "cleaned_datasets/cleaned_SUAS_final_report.txt"  # Change this to the path of your text file
ner_on_text_file(file_path)
# Out:
# Entity: 2023, Type: CARDINAL
# Entity: marc cruz, Type: PERSON
# Entity: abdul kalam, Type: PERSON
# Entity: max gross joshua estrada, Type: PERSON
# Entity: jason mar josh, Type: PERSON
# Entity: ng ethan, Type: PERSON
# Entity: sarkis gafayan rubayet, Type: ORG
# Entity: david jackson, Type: PERSON
# Entity: 21 2023, Type: DATE
# Entity: 1, Type: CARDINAL
# Entity: 2 2 fall 2023, Type: DATE
# Entity: 3 21, Type: CARDINAL
# Entity: 4 23, Type: CARDINAL
# Entity: august, Type: DATE
# Entity: 231, Type: CARDINAL
# Entity: 4 232, Type: CARDINAL
# Entity: 5 24, Type: CARDINAL
# Entity: 5 25, Type: CARDINAL
# Entity: 7 251, Type: CARDINAL
# Entity: 7 2511, Type: DATE
# Entity: 7 2511, Type: DATE
# Entity: 8 252, Type: CARDINAL
# Entity: 9 26, Type: CARDINAL
# Entity: october, Type: DATE
# Entity: 261, Type: CARDINAL
# Entity: 10 262, Type: CARDINAL
# Entity: 12 263, Type: CARDINAL
# Entity: october, Type: DATE
# Entity: 13 271, Type: CARDINAL
# Entity: 13, Type: CARDINAL
# ...
