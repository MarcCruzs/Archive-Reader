# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.8 MB 487.6 kB/s eta 0:00:27
#       --------------------------------------- 0.3/12.8 MB 2.4 MB/s eta 0:00:06
#      -- ------------------------------------- 0.9/12.8 MB 4.9 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.4/12.8 MB 6.5 MB/s eta 0:00:02
#      ------ --------------------------------- 2.0/12.8 MB 7.4 MB/s eta 0:00:02
#      ------- -------------------------------- 2.5/12.8 MB 8.0 MB/s eta 0:00:02
#      --------- ------------------------------ 3.1/12.8 MB 8.6 MB/s eta 0:00:02
#      ----------- ---------------------------- 3.6/12.8 MB 8.9 MB/s eta 0:00:02
#      ------------- -------------------------- 4.2/12.8 MB 9.2 MB/s eta 0:00:01
#      -------------- ------------------------- 4.8/12.8 MB 9.5 MB/s eta 0:00:01
# ...

# %%
import spacy

# Load the pre-trained English NER model
nlp = spacy.load("en_core_web_sm")

def ner_on_text_file(file_path, output_file):
    # Read the text from the file
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read()

    # Process the text with the NER model
    doc = nlp(text)
    
    # Open the output file to write the named entities
    with open(output_file, 'w', encoding='utf-8') as out_file:
        # Write the named entities to the output file
        for ent in doc.ents:
            # Split multi-word entities into individual words
            words = ent.text.split()
            for word in words:
                out_file.write(f"Entity: {word}, Type: {ent.label_}\n")
                print(f"Entity: {word}, Type: {ent.label_}\n")

# Example usage
file_path = "cleaned_datasets/cleaned_SUAS_final_report.txt"
output_file_path = "cleaned_datasets/NER_output_entities.txt"
ner_on_text_file(file_path, output_file_path)
# Out:
# Entity: 2023, Type: CARDINAL
#
# Entity: marc, Type: PERSON
#
# Entity: cruz, Type: PERSON
#
# Entity: abdul, Type: PERSON
#
# Entity: kalam, Type: PERSON
#
# Entity: max, Type: PERSON
#
# Entity: gross, Type: PERSON
#
# Entity: joshua, Type: PERSON
#
# Entity: estrada, Type: PERSON
#
# Entity: jason, Type: PERSON
#
# Entity: mar, Type: PERSON
#
# Entity: josh, Type: PERSON
#
# Entity: ng, Type: PERSON
#
# Entity: ethan, Type: PERSON
#
# Entity: sarkis, Type: ORG
#
# Entity: gafayan, Type: ORG
#
# Entity: rubayet, Type: ORG
#
# Entity: david, Type: PERSON
#
# Entity: jackson, Type: PERSON
#
# Entity: 21, Type: DATE
#
# Entity: 2023, Type: DATE
#
# Entity: 1, Type: CARDINAL
#
# Entity: 2, Type: DATE
#
# Entity: 2, Type: DATE
#
# Entity: fall, Type: DATE
#
# Entity: 2023, Type: DATE
#
# Entity: 3, Type: CARDINAL
#
# Entity: 21, Type: CARDINAL
#
# Entity: 4, Type: CARDINAL
#
# Entity: 23, Type: CARDINAL
#
# Entity: august, Type: DATE
#
# Entity: 231, Type: CARDINAL
#
# ...
